# %% [markdown]
# # 方法一：更改 plt.rcParams['font.family'] 設定

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fig = plt.figure(figsize=(6,4))
x = [1,2,3,4,5]
y = [123,432,823,192,12]

plt.rcParams['font.family']='SimHei' #使用中文字體（黑體）

plt.bar(x,y,align='center')
plt.title('中文標題') #標題名稱
plt.xlabel('X軸') #X軸名稱
plt.ylabel('Y軸') #Y軸名稱
plt.xticks(x, ['刻度A','刻度B','刻度C','刻度D','刻度E']) #X軸刻度名稱

plt.show()

# %% [markdown]
# ##  尋找matplotlib中可用字體
# 註：需知道中文字體的英文名稱

# %%
import matplotlib
[f.name for f in matplotlib.font_manager.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'cmb10',
#  'cmtt10',
#  'cmex10',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Serif Display',
#  'STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'cmmi10',
#  'Meiryo',
#  'Estrangelo Nisibin Outline',
#  'Charlemagne Std',
#  'Letter Gothic Std',
#  '.SF Compact Text',
#  'Luxi Sans',
#  'Candara',
#  'MingLiU_HKSCS-ExtB',
#  '.SF NS Text Condensed',
#  'Adobe Heiti Std',
#  'Luxi Sans',
#  'Candara',
#  'Letter Gothic Std',
#  'Luxi Mono',
#  'STIXSizeOneSym',
#  'Consolas',
#  'Luxi Serif',
#  'Adobe Gurmukhi',
#  'Adobe Caslon Pro',
#  'Kozuka Gothic Pr6N',
#  'Luxi Serif',
#  'Wingdings',
#  'Chaparral Pro',
#  'Verdana',
#  'Kozuka Mincho Pro',
#  'Corbel',
#  'Luxi Serif',
#  'Georgia',
#  'Franklin Gothic Book',
#  'Myriad Pro',
#  'Serto Urhoy',
#  'STIXNonUnicode',
#  'Courier New',
#  'Source Sans Pro',
#  'Minion Pro',
#  'Luxi Serif',
#  'Kozuka Gothic Pr6N',
#  'Source Sans Pro',
#  'Serto Mardin',
#  'Bitstream Vera Serif',
#  'Kozuka Gothic Pr6N',
#  'Luminari',
#  'Bitstream Vera Sans',
#  'Bitstream Vera Sans',
#  'Adobe Fan Heiti Std',
#  'Adobe Garamond Pro',
#  'Serto Batnan',
#  'Meiryo',
#  '.SF NS Display Condensed',
#  'Plantagenet Cherokee',
#  'Bodoni Ornaments',
#  'Myriad Hebrew',
#  'Adobe Arabic',
#  'PMingLiU',
#  '.SF Compact Display',
#  'AppleMyungjo',
#  'Georgia',
#  'Bitstream Vera Sans',
#  '.SF NS Text Condensed',
#  'Bitstream Vera Sans Mono',
#  'Kozuka Mincho Pr6N',
#  'Herculanum',
#  'East Syriac Ctesiphon',
#  'Minion Pro',
#  'Verdana',
#  'Nueva Std',
#  'Arial Narrow',
#  '.SF Compact Text',
#  'Minion Pro',
#  'Meiryo',
#  'Bitstream Vera Sans Mono',
#  'Adobe Arabic',
#  'Goha-Tibeb Zemen',
#  'Bitstream Vera Sans',
#  'Nueva Std',
#  'Stencil Std',
#  'Chaparral Pro',
#  'Symbol',
#  'Chaparral Pro',
#  'Serto Mardin',
#  'Lao Sangam MN',
#  '.SF Compact Rounded',
#  '.SF NS Display Condensed',
#  'Source Sans Pro',
#  '.SF Compact Text',
#  'Lithos Pro',
#  'MingLiU_HKSCS',
#  'Zapfino',
#  'Adobe Devanagari',
#  'Myriad Pro',
#  'Source Sans Pro',
#  'Constantia',
#  'Meiryo',
#  'Estrangelo Talada',
#  'Blackoak Std',
#  'Tw Cen MT',
#  'Serto Jerusalem',
#  'AppleGothic',
#  'Bitstream Vera Sans Mono',
#  'Kozuka Mincho Pr6N',
#  'Bitstream Vera Serif',
#  'Arial',
#  'Estrangelo Antioch',
#  'Consolas',
#  'Verdana',
#  'Georgia',
#  'Kozuka Gothic Pr6N',
#  'Luxi Mono',
#  'Apple Braille',
#  'Chalkduster',
#  'Brush Script Std',
#  'Tw Cen MT',
#  'Marlett',
#  'Luxi Sans',
#  'Estrangelo Quenneshrin',
#  'Times New Roman',
#  'STIXNonUnicode',
#  'Adobe Hebrew',
#  'Cambria',
#  '.SF Compact Rounded',
#  'InaiMathi',
#  'Times New Roman',
#  'STIXGeneral',
#  'Arial',
#  'Palatino Linotype',
#  'Diwan Thuluth',
#  'STIXVariants',
#  'Perpetua',
#  'Palatino Linotype',
#  'Serto Malankara',
#  '.SF Compact Display',
#  'Luxi Mono',
#  'Estrangelo Midyat',
#  'Kozuka Gothic Pr6N',
#  'Gill Sans MT',
#  'Cooper Std',
#  'Trattatello',
#  'Khmer Sangam MN',
#  'Cambria',
#  'Serto Jerusalem',
#  'Birch Std',
#  'Serto Jerusalem Outline',
#  'Myriad Arabic',
#  'Adobe Hebrew',
#  'Kozuka Gothic Pr6N',
#  'Bitstream Vera Sans Mono',
#  'Courier New',
#  '.SF Compact Text',
#  'TeamViewer11',
#  '.SF NS Display Condensed',
#  'Adobe Garamond Pro',
#  'Myriad Arabic',
#  'Kozuka Mincho Pr6N',
#  'Mishafi Gold',
#  'Serto Urhoy',
#  'Sathu',
#  'Wingdings 2',
#  'Serto Jerusalem',
#  'Kozuka Mincho Pro',
#  'MingLiU-ExtB',
#  'Kozuka Mincho Pr6N',
#  'Myriad Pro',
#  'STIXGeneral',
#  'Letter Gothic Std',
#  'Adobe Arabic',
#  'Brush Script MT',
#  'Cambria Math',
#  'Trajan Pro',
#  'Corbel',
#  '.SF Compact Rounded',
#  'Apple Braille',
#  'Silom',
#  'Times New Roman',
#  '.SF NS Display Condensed',
#  'DIN Alternate',
#  'Lithos Pro',
#  '.SF Compact Text',
#  'Serto Kharput',
#  'STIXSizeTwoSym',
#  'Apple Braille',
#  'Tekton Pro',
#  'Microsoft JhengHei',
#  '.SF NS Text Condensed',
#  'Goha-Tibeb Zemen',
#  'Kozuka Mincho Pr6N',
#  '.SF Compact Rounded',
#  'Adobe Caslon Pro',
#  'Adobe Ming Std',
#  'STIXIntegralsUpSm',
#  'STIXSizeTwoSym',
#  'Myriad Pro',
#  'Comic Sans MS',
#  '.SF Compact Display',
#  'Serto Batnan',
#  'Gulim',
#  'Adobe Song Std',
#  'STIXIntegralsSm',
#  'Luxi Mono',
#  'Myriad Hebrew',
#  'STIXNonUnicode',
#  'Minion Pro',
#  '.SF Compact Rounded',
#  'Andale Mono',
#  'DIN Condensed',
#  'Constantia',
#  'Webdings',
#  'Verdana',
#  'Minion Pro',
#  'Cambria',
#  'Estrangelo Nisibin',
#  '.SF Compact Text',
#  '.SF NS Display Condensed',
#  'Myriad Arabic',
#  'Trebuchet MS',
#  'Arial',
#  'Estrangelo TurAbdin',
#  'Source Sans Pro',
#  'Kozuka Mincho Pro',
#  'Palatino Linotype',
#  'STIXIntegralsUpD',
#  'Adobe Caslon Pro',
#  'System Font',
#  '.SF NS Text Condensed',
#  'Arial Narrow',
#  'STIXGeneral',
#  'Tekton Pro',
#  'Adobe Garamond Pro',
#  'STIXGeneral',
#  'STIXVariants',
#  'Apple Chancery',
#  'STIXIntegralsUp',
#  'Gill Sans MT',
#  'Adobe Caslon Pro',
#  'Kozuka Gothic Pro',
#  'Prestige Elite Std',
#  'Microsoft Tai Le',
#  'Apple Braille',
#  'Estrangelo Edessa',
#  'Kokonor',
#  'Minion Pro',
#  'Microsoft Tai Le',
#  'Trajan Pro 3',
#  'Kozuka Gothic Pro',
#  '.SF Compact Display',
#  'Luxi Sans',
#  'Adobe Myungjo Std',
#  'Arial Unicode MS',
#  'Gurmukhi MT',
#  'East Syriac Adiabene',
#  'Adobe Naskh',
#  'Trajan Pro',
#  'Calibri',
#  '.SF NS Display Condensed',
#  'Impact',
#  'Courier New',
#  'Source Sans Pro',
#  'Source Sans Pro',
#  'Tw Cen MT',
#  'Tekton Pro',
#  'Myriad Hebrew',
#  '.SF Compact Text',
#  'Nueva Std',
#  'Arial Narrow',
#  'Myriad Hebrew',
#  'Lucida Console',
#  'Perpetua',
#  '.SF Compact Text',
#  'Consolas',
#  'Apple Symbols',
#  'Microsoft Sans Serif',
#  'Big Caslon',
#  'Myriad Pro',
#  '.SF NS Display Condensed',
#  'Adobe Devanagari',
#  'Adobe Gurmukhi',
#  'Gill Sans MT',
#  'Arial Rounded MT Bold',
#  'STIXSizeThreeSym',
#  '.SF Compact Rounded',
#  'Trebuchet MS',
#  'Bodoni 72 Smallcaps',
#  'SimSun',
#  'Orator Std',
#  'Myriad Pro',
#  'Adobe Devanagari',
#  'MingLiU',
#  'Tahoma',
#  'Georgia',
#  'Adobe Caslon Pro',
#  'Trajan Pro 3',
#  'Krungthep',
#  'Corbel',
#  'Myriad Pro',
#  'Arial',
#  'Orator Std',
#  '.SF Compact Rounded',
#  'Corbel',
#  'Courier New',
#  '.LastResort',
#  'Minion Pro',
#  'System Font',
#  'Nueva Std',
#  '.SF Compact Display',
#  '.Keyboard',
#  'Poplar Std',
#  'Batang',
#  'SimSun-ExtB',
#  'Adobe Garamond Pro',
#  '.SF Compact Text',
#  'Arial Narrow',
#  'Hobo Std',
#  'Mishafi',
#  'STIXIntegralsD',
#  'Wingdings 3',
#  'Adobe Gothic Std',
#  'MS Reference Sans Serif',
#  'Adobe Hebrew',
#  '.SF Compact Display',
#  'SetoFont',
#  'Perpetua',
#  'SimHei',
#  'STIXSizeThreeSym',
#  '.SF Compact Rounded',
#  'Giddyup Std',
#  'Adobe Fangsong Std',
#  'Adobe Hebrew',
#  'Source Sans Pro',
#  'Bookshelf Symbol 7',
#  'Times New Roman',
#  'Kozuka Mincho Pr6N',
#  'Tekton Pro',
#  'STIXIntegralsSm',
#  'Source Sans Pro',
#  'Lucida Sans Unicode',
#  'Perpetua',
#  'Franklin Gothic Book',
#  '.SF Compact Text',
#  'Kozuka Gothic Pro',
#  'Myriad Pro',
#  'STIXSizeOneSym',
#  'Microsoft Himalaya',
#  'STIXNonUnicode',
#  'Adobe Devanagari',
#  'MS Reference Specialty',
#  'Palatino Linotype',
#  'Mesquite Std',
#  'Letter Gothic Std',
#  'Kozuka Mincho Pro',
#  'Minion Pro',
#  'Source Sans Pro',
#  'Adobe Kaiti Std',
#  '.SF Compact Display',
#  'Adobe Arabic',
#  'Cambria',
#  'Tw Cen MT',
#  'System Font',
#  'Kozuka Mincho Pro',
#  'STIXSizeFourSym',
#  'PMingLiU-ExtB',
#  'Adobe Caslon Pro',
#  '.SF NS Text Condensed',
#  '.SF NS Text Condensed',
#  'STIXSizeFiveSym',
#  'Constantia',
#  'Calibri',
#  'Gabriola',
#  'MS Mincho',
#  'Constantia',
#  'Kozuka Mincho Pro',
#  'Zapf Dingbats',
#  '.SF Compact Display',
#  'Comic Sans MS',
#  'Chaparral Pro',
#  'Nueva Std',
#  'Mongolian Baiti',
#  'Kozuka Gothic Pro',
#  'MS Gothic',
#  'OCR A Std',
#  'Myriad Arabic',
#  'Trebuchet MS',
#  'Hoefler Text',
#  'Franklin Gothic Medium',
#  'Kozuka Gothic Pro',
#  'Calibri',
#  'Chaparral Pro',
#  '.SF Compact Rounded',
#  'Cooper Std',
#  'Source Sans Pro',
#  'STIXIntegralsD',
#  'Consolas',
#  'MS PMincho',
#  '.SF Compact Text',
#  'STIXIntegralsUp',
#  'Candara',
#  'MS PGothic',
#  'Skia',
#  'STIXIntegralsUpSm',
#  'STIXSizeFourSym',
#  'STIXIntegralsUpD',
#  '.SF Compact Display',
#  'Nueva Std',
#  'Minion Pro',
#  'Franklin Gothic Medium',
#  'Myriad Pro',
#  'Calibri',
#  'Rosewood Std',
#  'Minion Pro',
#  'Microsoft Yi Baiti',
#  'Bradley Hand',
#  'Tahoma',
#  '.SF NS Display Condensed',
#  'Ayuthaya',
#  'Farisi',
#  'Source Sans Pro',
#  'Apple Braille',
#  '.SF Compact Text',
#  'Kozuka Gothic Pro',
#  'Candara',
#  'Trebuchet MS',
#  '.SF NS Display Condensed',
#  'Arial Black',
#  'Myriad Pro',
#  'Gill Sans MT']

# %% [markdown]
# # 方法二：每次作圖使用特定字體

# %%
font1 = {'fontname':'SetoFont'}
font2 = {'fontname':'SimSun'}
font3 = {'fontname':'SimHei'}

plt.bar(x,y,align='center')
plt.title('瀨戶字體標題',**font1, fontsize=18) #標題名稱
plt.xlabel('新宋字體X軸',**font2, fontsize=18) #X軸名稱
plt.ylabel('黑體Y軸',**font3, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# # 方法三、直接指定字體路徑

# %%
from matplotlib.font_manager import FontProperties
font = FontProperties(fname='/Library/Fonts/Microsoft/Microsoft Jhenghei.ttf')

plt.bar(x,y,align='center')
plt.title('微軟正黑體標題',fontproperties=font, fontsize=18) #標題名稱
plt.xlabel('微軟正黑體X軸',fontproperties=font, fontsize=18) #X軸名稱
plt.ylabel('微軟正黑體Y軸',fontproperties=font, fontsize=18) #Y軸名稱
plt.show()

# %% [markdown]
# ## 測試中文字體Notes:
# ### Mac可用字體：SimHei
# ### Windows 7可用字體：Microsoft YaHei
# ### Windows 10 可用字體：DFKai-SB
