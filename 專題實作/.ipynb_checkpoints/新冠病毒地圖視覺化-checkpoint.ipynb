# %% [markdown]
# # 新冠病毒地圖視覺化
#
# 修改自：https://github.com/joaotinti75/Coronavirus/blob/master/corona_virus.ipynb

# %%
import pandas as pd

# %% [markdown]
# ### 下載最新資料
# 資料來源（Johns Hopkins University）：https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data?fbclid=IwAR1C6Cf_k5bpeEF5v1I9G-OlXeMZd0B1JreUw4ayc5tuOLYVSKvyunFaam8

# %%
from datetime import datetime, timedelta

lasted_day = datetime.today() - timedelta(2) # 時差與疫情統計時間問題，先簡單處理為爬取目前台灣時間之前兩天資料
print(lasted_day.year, lasted_day.month, lasted_day.day)
# Out:
# 2020 3 4

# %%
# 數字加0處理
lasted_day_year = str(lasted_day.year)
if(lasted_day.month < 10):
    lasted_day_month = '0' + str(lasted_day.month)
if(lasted_day.day < 10):
    lasted_day_day = '0' + str(lasted_day.day)

# %%
base_url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports'
download_link = base_url + '/' + lasted_day_month + '-' + lasted_day_day + '-' + lasted_day_year + '.csv'
print(download_link)
# Out:
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-04-2020.csv

# %%
df = pd.read_csv(download_link)
df
# Out:
#                            Province/State   Country/Region  \
# 0                                   Hubei   Mainland China
# 1                                     NaN      South Korea
# 2                                     NaN            Italy
# 3                                     NaN             Iran
# 4                               Guangdong   Mainland China
# 5                                   Henan   Mainland China
# 6                                Zhejiang   Mainland China
# 7                                   Hunan   Mainland China
# 8                                   Anhui   Mainland China
# 9                                 Jiangxi   Mainland China
# 10                               Shandong   Mainland China
# 11           Diamond Princess cruise ship           Others
# 12                                Jiangsu   Mainland China
# 13                              Chongqing   Mainland China
# 14                                Sichuan   Mainland China
# ...

# %% [markdown]
# ## 累計確診個案數的經緯度位置

# %%
confirmed_loc = []
for i in range(len(df)):
    for j in range(df.loc[i,'Confirmed']):
        confirmed_loc.append([df.loc[i,'Latitude'],df.loc[i,'Longitude']])

# %%
# 目前總確診個案數
len(confirmed_loc)
# Out:
# 95124

# %% [markdown]
# ### 製作地圖視覺化：使用 folium
# https://python-visualization.github.io/folium/

# %%
import folium
from folium.plugins import HeatMap
mapa = folium.Map(location=[10,10],zoom_start=1.5,tiles='Stamen Toner')
HeatMap(confirmed_loc, radius=20).add_to(mapa)
mapa.save('corona_mapa.html')

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Sample

# %% [markdown]
# ![Image](coronavirus_sample_viz.png)
